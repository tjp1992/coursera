# %% [markdown]
# # Checking the data
# 1. Check the data types
# 2. Check the missing values
# 3. Check the duplicates
# 4. Check the outliers
# 5. Check the skewness

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv('IMDB_Top_250.csv')
df.head()
# Out:
#                                            title  runtime  \
# 0                       The Shawshank Redemption      142
# 1                                  The Godfather      175
# 2                                The Dark Knight      152
# 3  The Lord of the Rings: The Return of the King      201
# 4                               Schindler's List      195
#
#                        genre  rating  metascore    votes      gross  year  \
# 0                      Drama     9.3         81  2663689   28341469  1994
# 1               Crime, Drama     9.2        100  1845919  134966411  1972
# 2       Action, Crime, Drama     9.0         84  2636663  534858444  2008
# 3   Action, Adventure, Drama     9.0         94  1836493  377845905  2003
# 4  Biography, Drama, History     9.0         94  1348869   96898818  1993
#
#                director                                        description
# 0        Frank Darabont  Two imprisoned men bond over a number of years...
# ...

# %%
# checking the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        250 non-null    object
#  1   runtime      250 non-null    int64
#  2   genre        250 non-null    object
#  3   rating       250 non-null    float64
#  4   metascore    250 non-null    int64
#  5   votes        250 non-null    int64
#  6   gross        250 non-null    int64
#  7   year         250 non-null    object
#  8   director     250 non-null    object
#  9   description  250 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 19.7+ KB

# %%
# checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# checking for null values
df.isnull().sum()
# Out:
# title          0
# runtime        0
# genre          0
# rating         0
# metascore      0
# votes          0
# gross          0
# year           0
# director       0
# description    0
# dtype: int64

# %%
# checking for unique values
df.nunique()
# Out:
# title          250
# runtime        101
# genre          104
# rating          13
# metascore       46
# votes          250
# gross          245
# year            91
# director       154
# description    250
# dtype: int64

# %%
# checking for outliers
df.describe()
# Out:
#          runtime      rating   metascore         votes         gross
# count  250.00000  250.000000  250.000000  2.500000e+02  2.500000e+02
# mean   128.96400    8.309600   75.476000  6.357546e+05  8.630571e+07
# std     30.01557    0.228817   25.164388  5.137400e+05  1.325522e+08
# min     45.00000    8.000000    0.000000  3.009900e+04  2.100000e+01
# 25%    107.25000    8.100000   71.250000  2.215925e+05  2.489488e+06
# 50%    126.50000    8.200000   82.500000  4.909470e+05  2.527764e+07
# 75%    145.00000    8.400000   90.000000  9.545910e+05  1.274143e+08
# max    238.00000    9.300000  100.000000  2.663689e+06  8.583730e+08

# %%
# plot value_counts for director that appear more than 1 time
df['director'].value_counts()[df['director'].value_counts() > 1].plot(kind='bar', figsize=(10,5))
# Out:
# <AxesSubplot:>
