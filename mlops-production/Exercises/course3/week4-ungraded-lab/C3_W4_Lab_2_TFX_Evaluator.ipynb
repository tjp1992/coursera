# %% [markdown]
# # Ungraded Lab: Model Analysis with TFX Evaluator

# %% [markdown]
# Now that you've used TFMA as a standalone library in the previous lab, you will now see how it is used by TFX with its [Evaluator](https://www.tensorflow.org/tfx/guide/evaluator) component. This component comes after your `Trainer` run and it checks if your trained model meets the minimum required metrics and also compares it with previously generated models.
#
# You will go through a TFX pipeline that prepares and trains the same model architecture you used in the previous lab. As a reminder, this is a binary classifier to be trained on the [Census Income dataset](http://archive.ics.uci.edu/ml/datasets/Census+Income). Since you're already familiar with the earlier TFX components, we will just go over them quickly but we've placed notes on where you can modify code if you want to practice or produce a better result.
#
# Let's begin!
#
# *Credits: Some of the code and discussions are based on the TensorFlow team's [official tutorial](https://www.tensorflow.org/tfx/tutorials/tfx/components_keras).*

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Install TFX

# %%
# !pip install -U pip
# !pip install --use-deprecated=legacy-resolver tfx==1.7.0
# !pip install apache-beam==2.39.0
# Out:
# Requirement already satisfied: pip in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (22.3.1)
# Collecting tfx==1.7.0
#   Downloading tfx-1.7.0-py3-none-any.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 5.1 MB/s eta 0:00:0000:0100:01
# Collecting apache-beam[gcp]<3,>=2.36
#   Using cached apache_beam-2.43.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.5 MB)
# Collecting keras-tuner<2,>=1.0.4
#   Using cached keras_tuner-1.1.3-py3-none-any.whl (135 kB)
# Collecting tensorflow-data-validation<1.8.0,>=1.7.0
#   Downloading tensorflow_data_validation-1.7.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 5.6 MB/s eta 0:00:0000:0100:01m
# Collecting tensorflow-serving-api!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3,>=1.15
#   Downloading tensorflow_serving_api-2.10.1-py2.py3-none-any.whl (37 kB)
# Collecting ml-pipelines-sdk==1.7.0
#   Downloading ml_pipelines_sdk-1.7.0-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 4.6 MB/s eta 0:00:0000:0100:01m
# Collecting ml-metadata<1.8.0,>=1.7.0
#   Downloading ml_metadata-1.7.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 4.6 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: jinja2<4,>=2.7.3 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tfx==1.7.0) (3.1.2)
# Collecting attrs<21,>=19.3.0
#   Using cached attrs-20.3.0-py2.py3-none-any.whl (49 kB)
# Collecting tensorflow-hub<0.13,>=0.9.0
#   Using cached tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
# Collecting tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<2.9,>=1.15.5
#   Using cached tensorflow-2.8.4-cp38-cp38-manylinux2010_x86_64.whl (498.0 MB)
# Requirement already satisfied: numpy<2,>=1.16 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tfx==1.7.0) (1.19.5)
# Requirement already satisfied: pyyaml<6,>=3.12 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tfx==1.7.0) (5.4.1)
# Collecting tfx-bsl<1.8.0,>=1.7.0
#   Downloading tfx_bsl-1.7.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 4.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: google-api-python-client<2,>=1.8 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tfx==1.7.0) (1.12.11)
# Collecting portpicker<2,>=1.3.1
#   Using cached portpicker-1.5.2-py3-none-any.whl (14 kB)
# Collecting kubernetes<13,>=10.0.1
#   Using cached kubernetes-12.0.1-py2.py3-none-any.whl (1.7 MB)
# Collecting google-cloud-aiplatform<2,>=1.6.2
#   Downloading google_cloud_aiplatform-1.19.0-py2.py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 5.7 MB/s eta 0:00:0000:0100:01
# Collecting packaging<21,>=20
#   Using cached packaging-20.9-py2.py3-none-any.whl (40 kB)
# Requirement already satisfied: grpcio<2,>=1.28.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tfx==1.7.0) (1.34.1)
# Requirement already satisfied: protobuf<4,>=3.13 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tfx==1.7.0) (3.19.6)
# Collecting tensorflow-model-analysis<0.39,>=0.38.0
#   Downloading tensorflow_model_analysis-0.38.0-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 5.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tfx==1.7.0) (0.12.0)
# Requirement already satisfied: google-apitools<1,>=0.5 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tfx==1.7.0) (0.5.31)
# Collecting tensorflow-transform<1.8.0,>=1.7.0
#   Downloading tensorflow_transform-1.7.0-py3-none-any.whl (433 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.6/433.6 kB 5.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyarrow<6,>=1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tfx==1.7.0) (2.0.0)
# Collecting google-cloud-bigquery<3,>=2.26.0
#   Using cached google_cloud_bigquery-2.34.4-py2.py3-none-any.whl (206 kB)
# Collecting docker<5,>=4.1
#   Using cached docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting click<8,>=7
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# Requirement already satisfied: pydot<2,>=1.2.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (1.4.2)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (0.18)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (2.7.0)
# Requirement already satisfied: objsize<0.6.0,>=0.5.2 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (0.5.2)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (0.3.1.1)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (2.28.1)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (2.8.2)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (1.7.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (3.7.4.3)
# Requirement already satisfied: regex>=2020.6.8 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (2022.9.13)
# Requirement already satisfied: cloudpickle~=2.2.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (2.2.0)
# Requirement already satisfied: orjson<4.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (3.8.2)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (0.19.0)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (3.13.0)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (1.22.1)
# Requirement already satisfied: pytz>=2018.3 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (2022.1)
# Requirement already satisfied: httplib2<0.21.0,>=0.8 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (0.19.1)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (1.7)
# Requirement already satisfied: google-cloud-language<2,>=1.3.0; extra == "gcp" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (1.3.2)
# Requirement already satisfied: google-auth-httplib2<0.2.0,>=0.1.0; extra == "gcp" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (0.1.0)
# Requirement already satisfied: google-cloud-datastore<2,>=1.8.0; extra == "gcp" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (1.15.5)
# Requirement already satisfied: google-cloud-vision<2,>=0.38.0; extra == "gcp" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (1.0.2)
# Requirement already satisfied: google-cloud-videointelligence<2,>=1.8.0; extra == "gcp" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (1.16.3)
# Requirement already satisfied: google-cloud-bigquery-storage<2.14,>=2.6.3; extra == "gcp" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (2.13.2)
# Requirement already satisfied: google-cloud-core<3,>=0.28.1; extra == "gcp" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (1.7.3)
# Requirement already satisfied: google-auth<3,>=1.18.0; extra == "gcp" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (1.35.0)
# Requirement already satisfied: google-cloud-recommendations-ai<0.8.0,>=0.1.0; extra == "gcp" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (0.2.0)
# Requirement already satisfied: cachetools<5,>=3.1.0; extra == "gcp" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (4.2.4)
# Collecting google-cloud-pubsub<3,>=2.1.0; extra == "gcp"
#   Using cached google_cloud_pubsub-2.13.11-py2.py3-none-any.whl (236 kB)
# Requirement already satisfied: google-cloud-pubsublite<2,>=1.2.0; extra == "gcp" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (1.6.0)
# Collecting google-cloud-dlp<4,>=3.0.0; extra == "gcp"
#   Using cached google_cloud_dlp-3.9.2-py2.py3-none-any.whl (125 kB)
# Requirement already satisfied: google-cloud-bigtable<2,>=0.31.1; extra == "gcp" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (1.7.3)
# Collecting google-cloud-spanner<4,>=3.0.0; extra == "gcp"
#   Using cached google_cloud_spanner-3.23.0-py2.py3-none-any.whl (292 kB)
# Requirement already satisfied: tensorboard in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from keras-tuner<2,>=1.0.4->tfx==1.7.0) (2.10.1)
# Collecting kt-legacy
#   Using cached kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: ipython in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from keras-tuner<2,>=1.0.4->tfx==1.7.0) (7.34.0)
# Requirement already satisfied: pandas<2,>=1.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow-data-validation<1.8.0,>=1.7.0->tfx==1.7.0) (1.4.4)
# Collecting pyfarmhash<0.4,>=0.2
#   Using cached pyfarmhash-0.3.2.tar.gz (99 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six<2,>=1.12 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow-data-validation<1.8.0,>=1.7.0->tfx==1.7.0) (1.15.0)
# Collecting tensorflow-metadata<1.8,>=1.7.0
#   Downloading tensorflow_metadata-1.7.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: joblib<0.15,>=0.12 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow-data-validation<1.8.0,>=1.7.0->tfx==1.7.0) (0.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from jinja2<4,>=2.7.3->tfx==1.7.0) (2.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<2.9,>=1.15.5->tfx==1.7.0) (3.3.0)
# Collecting keras<2.9,>=2.8.0rc0
#   Using cached keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
# Requirement already satisfied: setuptools in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<2.9,>=1.15.5->tfx==1.7.0) (56.0.0)
# Requirement already satisfied: flatbuffers>=1.12 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<2.9,>=1.15.5->tfx==1.7.0) (1.12)
# Requirement already satisfied: gast>=0.2.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<2.9,>=1.15.5->tfx==1.7.0) (0.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<2.9,>=1.15.5->tfx==1.7.0) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<2.9,>=1.15.5->tfx==1.7.0) (1.12.1)
# Requirement already satisfied: h5py>=2.9.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<2.9,>=1.15.5->tfx==1.7.0) (3.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<2.9,>=1.15.5->tfx==1.7.0) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<2.9,>=1.15.5->tfx==1.7.0) (1.1.0)
# Requirement already satisfied: libclang>=9.0.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<2.9,>=1.15.5->tfx==1.7.0) (14.0.6)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<2.9,>=1.15.5->tfx==1.7.0) (1.1.2)
# Collecting tensorflow-estimator<2.9,>=2.8
#   Downloading tensorflow_estimator-2.8.0-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 kB 5.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<2.9,>=1.15.5->tfx==1.7.0) (0.27.0)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0; python_version >= "3" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from google-api-python-client<2,>=1.8->tfx==1.7.0) (1.33.2)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from google-api-python-client<2,>=1.8->tfx==1.7.0) (3.0.1)
# Requirement already satisfied: psutil in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from portpicker<2,>=1.3.1->tfx==1.7.0) (5.9.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from kubernetes<13,>=10.0.1->tfx==1.7.0) (1.4.1)
# Requirement already satisfied: certifi>=14.05.14 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from kubernetes<13,>=10.0.1->tfx==1.7.0) (2022.9.24)
# Requirement already satisfied: requests-oauthlib in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from kubernetes<13,>=10.0.1->tfx==1.7.0) (1.3.1)
# Requirement already satisfied: urllib3>=1.24.2 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from kubernetes<13,>=10.0.1->tfx==1.7.0) (1.26.12)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from google-cloud-aiplatform<2,>=1.6.2->tfx==1.7.0) (2.4.0)
# Collecting google-cloud-resource-manager<3.0.0dev,>=1.3.3
#   Downloading google_cloud_resource_manager-1.6.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 5.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pyparsing>=2.0.2 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from packaging<21,>=20->tfx==1.7.0) (2.4.7)
# Requirement already satisfied: scipy<2,>=1.4.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (1.8.1)
# Requirement already satisfied: ipywidgets<8,>=7 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (7.7.2)
# Requirement already satisfied: oauth2client>=1.4.12 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from google-apitools<1,>=0.5->tfx==1.7.0) (4.1.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from google-cloud-bigquery<3,>=2.26.0->tfx==1.7.0) (1.3.3)
# Requirement already satisfied: docopt in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (0.6.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (2.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from google-auth<3,>=1.18.0; extra == "gcp"->apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from google-auth<3,>=1.18.0; extra == "gcp"->apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (4.9)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from google-cloud-pubsub<3,>=2.1.0; extra == "gcp"->apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (0.12.4)
# Requirement already satisfied: grpcio-status>=1.16.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from google-cloud-pubsub<3,>=2.1.0; extra == "gcp"->apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (1.34.1)
# Requirement already satisfied: overrides<7.0.0,>=6.0.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from google-cloud-pubsublite<2,>=1.2.0; extra == "gcp"->apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (6.5.0)
# Requirement already satisfied: sqlparse>=0.3.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from google-cloud-spanner<4,>=3.0.0; extra == "gcp"->apache-beam[gcp]<3,>=2.36->tfx==1.7.0) (0.4.3)
# Requirement already satisfied: markdown>=2.6.8 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorboard->keras-tuner<2,>=1.0.4->tfx==1.7.0) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorboard->keras-tuner<2,>=1.0.4->tfx==1.7.0) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorboard->keras-tuner<2,>=1.0.4->tfx==1.7.0) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorboard->keras-tuner<2,>=1.0.4->tfx==1.7.0) (0.38.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorboard->keras-tuner<2,>=1.0.4->tfx==1.7.0) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorboard->keras-tuner<2,>=1.0.4->tfx==1.7.0) (2.2.2)
# Requirement already satisfied: matplotlib-inline in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipython->keras-tuner<2,>=1.0.4->tfx==1.7.0) (0.1.6)
# Requirement already satisfied: traitlets>=4.2 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipython->keras-tuner<2,>=1.0.4->tfx==1.7.0) (5.5.0)
# Requirement already satisfied: decorator in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipython->keras-tuner<2,>=1.0.4->tfx==1.7.0) (5.1.1)
# Requirement already satisfied: pygments in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipython->keras-tuner<2,>=1.0.4->tfx==1.7.0) (2.13.0)
# Requirement already satisfied: jedi>=0.16 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipython->keras-tuner<2,>=1.0.4->tfx==1.7.0) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipython->keras-tuner<2,>=1.0.4->tfx==1.7.0) (3.0.31)
# Requirement already satisfied: pickleshare in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipython->keras-tuner<2,>=1.0.4->tfx==1.7.0) (0.7.5)
# Requirement already satisfied: backcall in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipython->keras-tuner<2,>=1.0.4->tfx==1.7.0) (0.2.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipython->keras-tuner<2,>=1.0.4->tfx==1.7.0) (4.8.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from tensorflow-metadata<1.8,>=1.7.0->tensorflow-data-validation<1.8.0,>=1.7.0->tfx==1.7.0) (1.56.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from requests-oauthlib->kubernetes<13,>=10.0.1->tfx==1.7.0) (3.2.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (3.6.1)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0; python_version >= "3.6" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (1.1.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (6.15.3)
# Requirement already satisfied: pyasn1>=0.1.7 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from oauth2client>=1.4.12->google-apitools<1,>=0.5->tfx==1.7.0) (0.4.8)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0; python_version >= "3.5" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery<3,>=2.26.0->tfx==1.7.0) (1.5.0)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard->keras-tuner<2,>=1.0.4->tfx==1.7.0) (5.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from jedi>=0.16->ipython->keras-tuner<2,>=1.0.4->tfx==1.7.0) (0.8.3)
# Requirement already satisfied: wcwidth in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->keras-tuner<2,>=1.0.4->tfx==1.7.0) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython->keras-tuner<2,>=1.0.4->tfx==1.7.0) (0.7.0)
# Requirement already satisfied: notebook>=4.4.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (6.4.12)
# Requirement already satisfied: tornado>=6.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (6.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (7.4.3)
# Requirement already satisfied: debugpy>=1.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (1.6.3)
# Requirement already satisfied: pyzmq>=17 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (24.0.1)
# Requirement already satisfied: nest-asyncio in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (1.5.6)
# Requirement already satisfied: zipp>=0.5 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard->keras-tuner<2,>=1.0.4->tfx==1.7.0) (3.10.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (0.16.0)
# Requirement already satisfied: prometheus-client in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (0.15.0)
# Requirement already satisfied: nbconvert>=5 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (6.5.4)
# Requirement already satisfied: jupyter-core>=4.6.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (4.11.2)
# Requirement already satisfied: nbformat in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (5.7.0)
# Requirement already satisfied: argon2-cffi in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (1.8.0)
# Requirement already satisfied: entrypoints in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (0.7.0)
# Requirement already satisfied: bleach in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (5.0.1)
# Requirement already satisfied: tinycss2 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (1.5.0)
# Requirement already satisfied: lxml in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (4.9.1)
# Requirement already satisfied: defusedxml in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (0.7.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (4.16.0)
# Requirement already satisfied: fastjsonschema in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (2.16.2)
# Requirement already satisfied: argon2-cffi-bindings in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (21.2.0)
# Requirement already satisfied: webencodings in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (0.5.1)
# Requirement already satisfied: soupsieve>1.2 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (2.3.2.post1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10; python_version < "3.9" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (5.10.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (0.18.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (1.15.1)
# Requirement already satisfied: pycparser in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.39,>=0.38.0->tfx==1.7.0) (2.21)
# Building wheels for collected packages: pyfarmhash
#   Building wheel for pyfarmhash (setup.py) ... done
#   Created wheel for pyfarmhash: filename=pyfarmhash-0.3.2-cp38-cp38-linux_x86_64.whl size=102197 sha256=00f5d90274483539828d12936a3bde1bda7bb963a8e6eb10306a040328eb050e
#   Stored in directory: /home/tjp1992/.cache/pip/wheels/35/32/7f/1e591681730e2775f0a5dba2ff9741846ab3471e178e3f85ae
# Successfully built pyfarmhash
# Installing collected packages: packaging, google-cloud-bigquery, google-cloud-pubsub, google-cloud-dlp, google-cloud-spanner, apache-beam, kt-legacy, keras-tuner, pyfarmhash, keras, tensorflow-estimator, tensorflow, tensorflow-metadata, tensorflow-serving-api, tfx-bsl, tensorflow-data-validation, portpicker, docker, attrs, ml-metadata, ml-pipelines-sdk, tensorflow-hub, kubernetes, google-cloud-resource-manager, google-cloud-aiplatform, tensorflow-model-analysis, tensorflow-transform, click, tfx
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: google-cloud-bigquery
#     Found existing installation: google-cloud-bigquery 2.20.0
#     Uninstalling google-cloud-bigquery-2.20.0:
#       Successfully uninstalled google-cloud-bigquery-2.20.0
#   Attempting uninstall: google-cloud-pubsub
#     Found existing installation: google-cloud-pubsub 1.7.2
#     Uninstalling google-cloud-pubsub-1.7.2:
#       Successfully uninstalled google-cloud-pubsub-1.7.2
#   Attempting uninstall: google-cloud-dlp
#     Found existing installation: google-cloud-dlp 1.0.2
#     Uninstalling google-cloud-dlp-1.0.2:
#       Successfully uninstalled google-cloud-dlp-1.0.2
#   Attempting uninstall: google-cloud-spanner
#     Found existing installation: google-cloud-spanner 1.19.3
#     Uninstalling google-cloud-spanner-1.19.3:
#       Successfully uninstalled google-cloud-spanner-1.19.3
#   Attempting uninstall: apache-beam
#     Found existing installation: apache-beam 2.32.0
#     Uninstalling apache-beam-2.32.0:
#       Successfully uninstalled apache-beam-2.32.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.10.0
#     Uninstalling keras-2.10.0:
#       Successfully uninstalled keras-2.10.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.5.3
#     Uninstalling tensorflow-2.5.3:
#       Successfully uninstalled tensorflow-2.5.3
#   Attempting uninstall: tensorflow-metadata
#     Found existing installation: tensorflow-metadata 1.1.0
#     Uninstalling tensorflow-metadata-1.1.0:
#       Successfully uninstalled tensorflow-metadata-1.1.0
#   Attempting uninstall: tensorflow-serving-api
#     Found existing installation: tensorflow-serving-api 2.5.4
#     Uninstalling tensorflow-serving-api-2.5.4:
#       Successfully uninstalled tensorflow-serving-api-2.5.4
#   Attempting uninstall: tfx-bsl
#     Found existing installation: tfx-bsl 1.1.1
#     Uninstalling tfx-bsl-1.1.1:
#       Successfully uninstalled tfx-bsl-1.1.1
#   Attempting uninstall: tensorflow-data-validation
#     Found existing installation: tensorflow-data-validation 1.1.0
#     Uninstalling tensorflow-data-validation-1.1.0:
#       Successfully uninstalled tensorflow-data-validation-1.1.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
#   Attempting uninstall: tensorflow-model-analysis
#     Found existing installation: tensorflow-model-analysis 0.32.0
#     Uninstalling tensorflow-model-analysis-0.32.0:
#       Successfully uninstalled tensorflow-model-analysis-0.32.0
#   Attempting uninstall: tensorflow-transform
#     Found existing installation: tensorflow-transform 1.0.0
#     Uninstalling tensorflow-transform-1.0.0:
#       Successfully uninstalled tensorflow-transform-1.0.0
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
# ERROR: pip's legacy dependency resolver does not consider dependency conflicts when selecting packages. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.4 requires numpy>=1.20, but you'll have numpy 1.19.5 which is incompatible.
# tensorflow 2.8.4 requires tensorboard<2.9,>=2.8, but you'll have tensorboard 2.10.1 which is incompatible.
# tensorflow-serving-api 2.10.1 requires tensorflow<3,>=2.10.1, but you'll have tensorflow 2.8.4 which is incompatible.
# streamlit 1.11.1 requires pyarrow>=4.0, but you'll have pyarrow 2.0.0 which is incompatible.
# streamlit 1.11.1 requires typing-extensions>=3.10.0.0, but you'll have typing-extensions 3.7.4.3 which is incompatible.
# statsmodels 0.13.2 requires packaging>=21.3, but you'll have packaging 20.9 which is incompatible.
# pmdarima 2.0.1 requires numpy>=1.21, but you'll have numpy 1.19.5 which is incompatible.
# pandas-profiling 3.3.0 requires joblib~=1.1.0, but you'll have joblib 0.14.1 which is incompatible.
# pandas-gbq 0.17.9 requires pyarrow<10.0dev,>=3.0.0, but you'll have pyarrow 2.0.0 which is incompatible.
# google-cloud-pubsublite 1.6.0 requires grpcio<2.0.0dev,>=1.38.1, but you'll have grpcio 1.34.1 which is incompatible.
# google-cloud-pubsublite 1.6.0 requires grpcio-status<2.0.0dev,>=1.38.1, but you'll have grpcio-status 1.34.1 which is incompatible.
# google-cloud-pubsub 2.13.11 requires grpcio<2.0dev,>=1.38.1, but you'll have grpcio 1.34.1 which is incompatible.
# google-cloud-bigquery 2.34.4 requires grpcio<2.0dev,>=1.38.1, but you'll have grpcio 1.34.1 which is incompatible.
# db-dtypes 1.0.4 requires pyarrow<10.0dev,>=3.0.0, but you'll have pyarrow 2.0.0 which is incompatible.
# Successfully installed apache-beam-2.43.0 attrs-20.3.0 click-7.1.2 docker-4.4.4 google-cloud-aiplatform-1.19.0 google-cloud-bigquery-2.34.4 google-cloud-dlp-3.9.2 google-cloud-pubsub-2.13.11 google-cloud-resource-manager-1.6.3 google-cloud-spanner-3.23.0 keras-2.8.0 keras-tuner-1.1.3 kt-legacy-1.0.4 kubernetes-12.0.1 ml-metadata-1.7.0 ml-pipelines-sdk-1.7.0 packaging-20.9 portpicker-1.5.2 pyfarmhash-0.3.2 tensorflow-2.8.4 tensorflow-data-validation-1.7.0 tensorflow-estimator-2.8.0 tensorflow-hub-0.12.0 tensorflow-metadata-1.7.0 tensorflow-model-analysis-0.38.0 tensorflow-serving-api-2.10.1 tensorflow-transform-1.7.0 tfx-1.7.0 tfx-bsl-1.7.0
# Collecting apache-beam==2.39.0
#   Using cached apache_beam-2.39.0-cp38-cp38-manylinux2010_x86_64.whl (12.3 MB)
# Requirement already satisfied: cloudpickle<3,>=2.0.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (2.2.0)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (0.3.1.1)
# Requirement already satisfied: orjson<4.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (3.8.2)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (3.13.0)
# Requirement already satisfied: protobuf<4,>=3.12.2 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (3.19.6)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (2.7.0)
# Requirement already satisfied: httplib2<0.20.0,>=0.8 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (0.19.1)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.7.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (3.7.4.3)
# Requirement already satisfied: pydot<2,>=1.2.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (1.4.2)
# Requirement already satisfied: grpcio<2,>=1.29.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (1.34.1)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (1.7)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (1.7.0)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (1.22.1)
# Requirement already satisfied: pytz>=2018.3 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (2022.1)
# Requirement already satisfied: pyarrow<8.0.0,>=0.15.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (2.0.0)
# Requirement already satisfied: numpy<1.23.0,>=1.14.3 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (1.19.5)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from apache-beam==2.39.0) (2.28.1)
# Requirement already satisfied: six>=1.5.2 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from grpcio<2,>=1.29.0->apache-beam==2.39.0) (1.15.0)
# Requirement already satisfied: docopt in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam==2.39.0) (0.6.2)
# Requirement already satisfied: pyparsing<3,>=2.4.2 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from httplib2<0.20.0,>=0.8->apache-beam==2.39.0) (2.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0->apache-beam==2.39.0) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0->apache-beam==2.39.0) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0->apache-beam==2.39.0) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0->apache-beam==2.39.0) (1.26.12)
# Installing collected packages: apache-beam
#   Attempting uninstall: apache-beam
#     Found existing installation: apache-beam 2.43.0
#     Uninstalling apache-beam-2.43.0:
#       Successfully uninstalled apache-beam-2.43.0
# Successfully installed apache-beam-2.39.0

# %% [markdown]
# *Note: In Google Colab, you need to restart the runtime at this point to finalize updating the packages you just installed. You can do so by clicking the `Restart Runtime` at the end of the output cell above (after installation), or by selecting `Runtime > Restart Runtime` in the Menu bar. **Please do not proceed to the next section without restarting.** You can also ignore the errors about version incompatibility of some of the bundled packages because we won't be using those in this notebook.*

# %% [markdown]
# ### Imports

# %%
import os
import pprint

import tensorflow as tf
import tensorflow_model_analysis as tfma
from tfx import v1 as tfx

from tfx.orchestration.experimental.interactive.interactive_context import InteractiveContext

tf.get_logger().propagate = False
tf.get_logger().setLevel('ERROR')
pp = pprint.PrettyPrinter()
# Out:
# 2022-11-23 12:14:51.273834: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-23 12:14:51.273916: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ### Set up pipeline paths

# %%
# Location of the pipeline metadata store
_pipeline_root = './pipeline/'

# Directory of the raw data files
_data_root = './data/census'

_data_filepath = os.path.join(_data_root, "data.csv")

# %%
# Create the TFX pipeline files directory
# !mkdir {_pipeline_root}

# Create the dataset directory
# !mkdir -p {_data_root}

# %% [markdown]
# ### Download and prepare the dataset
#
# Here, you will download the training split of the [Census Income Dataset](http://archive.ics.uci.edu/ml/datasets/Census+Income). This is twice as large as the test dataset you used in the previous lab.

# %%
# Define filename and URL
TAR_NAME = 'C3_W4_Lab_2_data.tar.gz'
DATA_PATH = f'https://storage.googleapis.com/mlep-public/course_3/week4/{TAR_NAME}'

# Download dataset
# !wget -nc {DATA_PATH}

# Extract archive
# !tar xvzf {TAR_NAME}

# Delete archive
# !rm {TAR_NAME}
# Out:
# --2022-11-23 11:58:08--  https://storage.googleapis.com/mlep-public/course_3/week4/C3_W4_Lab_2_data.tar.gz
# Resolving storage.googleapis.com (storage.googleapis.com)... 34.64.4.80, 34.64.4.16, 34.64.4.48, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|34.64.4.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 418898 (409K) [application/x-gzip]
# Saving to: ‘C3_W4_Lab_2_data.tar.gz’
#
# C3_W4_Lab_2_data.ta 100%[===================>] 409.08K  --.-KB/s    in 0.06s
#
# 2022-11-23 11:58:09 (6.75 MB/s) - ‘C3_W4_Lab_2_data.tar.gz’ saved [418898/418898]
#
# ./data/census/data.csv

# %% [markdown]
# Take a quick look at the first few rows.

# %%
# Preview dataset
# !head {_data_filepath}
# Out:
# age,workclass,fnlwgt,education,education-num,marital-status,occupation,relationship,race,sex,capital-gain,capital-loss,hours-per-week,native-country,label
# 39,State-gov,77516,Bachelors,13,Never-married,Adm-clerical,Not-in-family,White,Male,2174,0,40,United-States,0
# 50,Self-emp-not-inc,83311,Bachelors,13,Married-civ-spouse,Exec-managerial,Husband,White,Male,0,0,13,United-States,0
# 38,Private,215646,HS-grad,9,Divorced,Handlers-cleaners,Not-in-family,White,Male,0,0,40,United-States,0
# 53,Private,234721,11th,7,Married-civ-spouse,Handlers-cleaners,Husband,Black,Male,0,0,40,United-States,0
# 28,Private,338409,Bachelors,13,Married-civ-spouse,Prof-specialty,Wife,Black,Female,0,0,40,Cuba,0
# 37,Private,284582,Masters,14,Married-civ-spouse,Exec-managerial,Wife,White,Female,0,0,40,United-States,0
# 49,Private,160187,9th,5,Married-spouse-absent,Other-service,Not-in-family,Black,Female,0,0,16,Jamaica,0
# 52,Self-emp-not-inc,209642,HS-grad,9,Married-civ-spouse,Exec-managerial,Husband,White,Male,0,0,45,United-States,1
# 31,Private,45781,Masters,14,Never-married,Prof-specialty,Not-in-family,White,Female,14084,0,50,United-States,1

# %% [markdown]
# ## TFX Pipeline

# %% [markdown]
# ### Create the InteractiveContext
#
# As usual, you will initialize the pipeline and use a local SQLite file for the metadata store.

# %%
# Initialize InteractiveContext
context = InteractiveContext(pipeline_root=_pipeline_root)
# Out:
# WARNING:absl:InteractiveContext metadata_connection_config not provided: using SQLite ML Metadata database at ./pipeline/metadata.sqlite.

# %% [markdown]
# ### ExampleGen
#
# You will start by ingesting the data through `CsvExampleGen`. The code below uses the default 2:1 train-eval split (i.e. 33% of the data goes to eval) but feel free to modify if you want. You can review splitting techniques [here](https://www.tensorflow.org/tfx/guide/examplegen#splitting_method).

# %%
# Run CsvExampleGen
example_gen = tfx.components.CsvExampleGen(input_base=_data_root)
context.run(example_gen)
# Out:
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.8 interpreter.
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 3
#     outputs:
#         examples: OutputChannel(artifact_type=Examples, producer_component_id=CsvExampleGen, output_key=examples, additional_properties={}, additional_custom_properties={}))

# %%
# Print split names and URI
artifact = example_gen.outputs['examples'].get()[0]
print(artifact.split_names, artifact.uri)
# Out:
# ["train", "eval"] ./pipeline/CsvExampleGen/examples/3

# %% [markdown]
# ### StatisticsGen
# You will then compute the statistics so it can be used by the next components.

# %%
# Run StatisticsGen
statistics_gen = tfx.components.StatisticsGen(
    examples=example_gen.outputs['examples'])
context.run(statistics_gen)
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.8 interpreter.
# ExecutionResult(
#     component_id: StatisticsGen
#     execution_id: 4
#     outputs:
#         statistics: OutputChannel(artifact_type=ExampleStatistics, producer_component_id=StatisticsGen, output_key=statistics, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# You can look at the visualizations below if you want to explore the data some more.

# %%
# Visualize statistics
context.show(statistics_gen.outputs['statistics'])
# Out:
# <b>Artifact at ./pipeline/StatisticsGen/statistics/4</b><br/><br/>
# <div><b>'train' split:</b></div><br/>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>
# <div><b>'eval' split:</b></div><br/>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ### SchemaGen
#
# You can then infer the dataset schema with [SchemaGen](https://www.tensorflow.org/tfx/guide/schemagen). This will be used to validate incoming data to ensure that it is formatted correctly.

# %%
# Run SchemaGen
schema_gen = tfx.components.SchemaGen(
    statistics=statistics_gen.outputs['statistics'])
context.run(schema_gen)
# Out:
# ExecutionResult(
#     component_id: SchemaGen
#     execution_id: 5
#     outputs:
#         schema: OutputChannel(artifact_type=Schema, producer_component_id=SchemaGen, output_key=schema, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# For simplicity, you will just accept the inferred schema but feel free to modify with the [TFDV API](https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv) if you want.

# %%
# Visualize the inferred Schema
context.show(schema_gen.outputs['schema'])
# Out:
# <b>Artifact at ./pipeline/SchemaGen/schema/5</b><br/><br/>
#                     Type  Presence Valency            Domain
# Feature name
# 'age'                INT  required                         -
# 'capital-gain'       INT  required                         -
# 'capital-loss'       INT  required                         -
# 'education'       STRING  required               'education'
# 'education-num'      INT  required                         -
# 'fnlwgt'             INT  required                         -
# 'hours-per-week'     INT  required                         -
# 'label'              INT  required                         -
# 'marital-status'  STRING  required          'marital-status'
# 'native-country'  STRING  required          'native-country'
# 'occupation'      STRING  required              'occupation'
# 'race'            STRING  required                    'race'
# 'relationship'    STRING  required            'relationship'
# 'sex'             STRING  required                     'sex'
# 'workclass'       STRING  required               'workclass'
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Values
# Domain
# 'education'                                                                                                                                                                                                                                                                                                                                       '10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th', '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate', 'HS-grad', 'Masters', 'Preschool', 'Prof-school', 'Some-college'
# 'marital-status'                                                                                                                                                                                                                                                                                                                                                                                                'Divorced', 'Married-AF-spouse', 'Married-civ-spouse', 'Married-spouse-absent', 'Never-married', 'Separated', 'Widowed'
# 'native-country'  '?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba', 'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England', 'France', 'Germany', 'Greece', 'Guatemala', 'Haiti', 'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India', 'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos', 'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Puerto-Rico', 'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago', 'United-States', 'Vietnam', 'Yugoslavia'
# 'occupation'                                                                                                                                                                                                                                                                  '?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair', 'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners', 'Machine-op-inspct', 'Other-service', 'Priv-house-serv', 'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support', 'Transport-moving'
# 'race'                                                                                                                                                                                                                                                                                                                                                                                                                                                            'Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other', 'White'
# 'relationship'                                                                                                                                                                                                                                                                                                                                                                                                                                           'Husband', 'Not-in-family', 'Other-relative', 'Own-child', 'Unmarried', 'Wife'
# 'sex'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'Female', 'Male'
# 'workclass'                                                                                                                                                                                                                                                                                                                                                                                                  '?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private', 'Self-emp-inc', 'Self-emp-not-inc', 'State-gov', 'Without-pay'

# %% [markdown]
# ### ExampleValidator
#
# Next, run `ExampleValidator` to check if there are anomalies in the data.

# %%
# Run ExampleValidator
example_validator = tfx.components.ExampleValidator(
    statistics=statistics_gen.outputs['statistics'],
    schema=schema_gen.outputs['schema'])
context.run(example_validator)
# Out:
# ExecutionResult(
#     component_id: ExampleValidator
#     execution_id: 6
#     outputs:
#         anomalies: OutputChannel(artifact_type=ExampleAnomalies, producer_component_id=ExampleValidator, output_key=anomalies, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# If you just used the inferred schema, then there should not be any anomalies detected. If you modified the schema, then there might be some results here and you can again use TFDV to modify or relax constraints as needed.
#
# In actual deployments, this component will also help you understand how your data evolves over time and identify data errors. For example, the first batches of data that you get from your users might conform to the schema but it might not be the case after several months. This component will detect that and let you know that your model might need to be updated.

# %%
# Check results
context.show(example_validator.outputs['anomalies'])
# Out:
# <b>Artifact at ./pipeline/ExampleValidator/anomalies/6</b><br/><br/>
# <div><b>'train' split:</b></div><br/>
# <h4 style="color:green;">No anomalies found.</h4>
# <div><b>'eval' split:</b></div><br/>
# <h4 style="color:green;">No anomalies found.</h4>

# %% [markdown]
# ### Transform
#
# Now you will perform feature engineering on the training data. As shown when you previewed the CSV earlier, the data is still in raw format and cannot be consumed by the model just yet. The transform code in the following cells will take care of scaling your numeric features and one-hot encoding your categorical variables.
#
# *Note: If you're running this exercise for the first time, we advise that you leave the transformation code as is. After you've gone through the entire notebook, then you can modify these for practice and see what results you get. Just make sure that your model builder code in the `Trainer` component will also reflect those changes if needed. For example, removing a feature here should also remove an input layer for that feature in the model.*

# %%
# Set the constants module filename
_census_constants_module_file = 'census_constants.py'

# %%
# %%writefile {_census_constants_module_file}
#
# # Features with string data types that will be converted to indices
# VOCAB_FEATURE_DICT = {
#     'education': 16, 'marital-status': 7, 'occupation': 15, 'race': 5,
#     'relationship': 6, 'workclass': 9, 'sex': 2, 'native-country': 42
# }
#
# # Numerical features that are marked as continuous
# NUMERIC_FEATURE_KEYS = ['fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
#
# # Feature that can be grouped into buckets
# BUCKET_FEATURE_DICT = {'age': 4}
#
# # Number of out-of-vocabulary buckets
# NUM_OOV_BUCKETS = 5
#
# # Feature that the model will predict
# LABEL_KEY = 'label'
# Out:
# Writing census_constants.py

# %%
# Set the transform module filename
_census_transform_module_file = 'census_transform.py'

# %%
# %%writefile {_census_transform_module_file}
#
# import tensorflow as tf
# import tensorflow_transform as tft
#
# # import constants from cells above
# import census_constants
#
# # Unpack the contents of the constants module
# _NUMERIC_FEATURE_KEYS = census_constants.NUMERIC_FEATURE_KEYS
# _VOCAB_FEATURE_DICT = census_constants.VOCAB_FEATURE_DICT
# _BUCKET_FEATURE_DICT = census_constants.BUCKET_FEATURE_DICT
# _NUM_OOV_BUCKETS = census_constants.NUM_OOV_BUCKETS
# _LABEL_KEY = census_constants.LABEL_KEY
#
# # Define the transformations
# def preprocessing_fn(inputs):
#     """tf.transform's callback function for preprocessing inputs.
#     Args:
#         inputs: map from feature keys to raw not-yet-transformed features.
#     Returns:
#         Map from string feature key to transformed feature operations.
#     """
#
#     # Initialize outputs dictionary
#     outputs = {}
#
#     # Scale these features to the range [0,1]
#     for key in _NUMERIC_FEATURE_KEYS:
#         scaled = tft.scale_to_0_1(inputs[key])
#         outputs[key] = tf.reshape(scaled, [-1])
#
#     # Convert strings to indices and convert to one-hot vectors
#     for key, vocab_size in _VOCAB_FEATURE_DICT.items():
#         indices = tft.compute_and_apply_vocabulary(inputs[key], num_oov_buckets=_NUM_OOV_BUCKETS)
#         one_hot = tf.one_hot(indices, vocab_size + _NUM_OOV_BUCKETS)
#         outputs[key] = tf.reshape(one_hot, [-1, vocab_size + _NUM_OOV_BUCKETS])
#
#     # Bucketize this feature and convert to one-hot vectors
#     for key, num_buckets in _BUCKET_FEATURE_DICT.items():
#         indices = tft.bucketize(inputs[key], num_buckets)
#         one_hot = tf.one_hot(indices, num_buckets)
#         outputs[key] = tf.reshape(one_hot, [-1, num_buckets])
#
#     # Cast label to float
#     outputs[_LABEL_KEY] = tf.cast(inputs[_LABEL_KEY], tf.float32)
#
#     return outputs
# Out:
# Writing census_transform.py

# %% [markdown]
# Now, we pass in this feature engineering code to the `Transform` component and run it to transform your data.

# %%
# Run the Transform component
transform = tfx.components.Transform(
    examples=example_gen.outputs['examples'],
    schema=schema_gen.outputs['schema'],
    module_file=os.path.abspath(_census_transform_module_file))
context.run(transform, enable_cache=False)
# Out:
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying census_transform.py -> build/lib
# copying census_constants.py -> build/lib
# installing to /tmp/tmp_ogrmt8u
# running install
# running install_lib
# copying build/lib/census_transform.py -> /tmp/tmp_ogrmt8u
# copying build/lib/census_constants.py -> /tmp/tmp_ogrmt8u
# running install_egg_info
# running egg_info
# creating tfx_user_code_Transform.egg-info
# writing tfx_user_code_Transform.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Transform.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Transform.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# listing git files failed - pretending there aren't any
# reading manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# Copying tfx_user_code_Transform.egg-info to /tmp/tmp_ogrmt8u/tfx_user_code_Transform-0.0+b4cdffd259c88473f714b412cc62df1dc81614e72429a198acc51340f3a1f977-py3.8.egg-info
# running install_scripts
# creating /tmp/tmp_ogrmt8u/tfx_user_code_Transform-0.0+b4cdffd259c88473f714b412cc62df1dc81614e72429a198acc51340f3a1f977.dist-info/WHEEL
# creating '/tmp/tmp0h4wokrk/tfx_user_code_Transform-0.0+b4cdffd259c88473f714b412cc62df1dc81614e72429a198acc51340f3a1f977-py3-none-any.whl' and adding '/tmp/tmp_ogrmt8u' to it
# adding 'census_constants.py'
# adding 'census_transform.py'
# adding 'tfx_user_code_Transform-0.0+b4cdffd259c88473f714b412cc62df1dc81614e72429a198acc51340f3a1f977.dist-info/METADATA'
# adding 'tfx_user_code_Transform-0.0+b4cdffd259c88473f714b412cc62df1dc81614e72429a198acc51340f3a1f977.dist-info/WHEEL'
# adding 'tfx_user_code_Transform-0.0+b4cdffd259c88473f714b412cc62df1dc81614e72429a198acc51340f3a1f977.dist-info/top_level.txt'
# adding 'tfx_user_code_Transform-0.0+b4cdffd259c88473f714b412cc62df1dc81614e72429a198acc51340f3a1f977.dist-info/RECORD'
# removing /tmp/tmp_ogrmt8u
# Processing ./pipeline/_wheels/tfx_user_code_Transform-0.0+b4cdffd259c88473f714b412cc62df1dc81614e72429a198acc51340f3a1f977-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+b4cdffd259c88473f714b412cc62df1dc81614e72429a198acc51340f3a1f977
# Processing ./pipeline/_wheels/tfx_user_code_Transform-0.0+b4cdffd259c88473f714b412cc62df1dc81614e72429a198acc51340f3a1f977-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+b4cdffd259c88473f714b412cc62df1dc81614e72429a198acc51340f3a1f977
# Processing ./pipeline/_wheels/tfx_user_code_Transform-0.0+b4cdffd259c88473f714b412cc62df1dc81614e72429a198acc51340f3a1f977-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+b4cdffd259c88473f714b412cc62df1dc81614e72429a198acc51340f3a1f977
# 2022-11-23 12:26:01.078779: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-11-23 12:26:01.080070: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-11-23 12:26:01.080139: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (DESKTOP-QTA8L7J): /proc/driver/nvidia/version does not exist
# 2022-11-23 12:26:01.084661: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: Tuple[Dict[str, Union[NoneType, _Dataset]], Union[Dict[str, Dict[str, PCollection]], NoneType], int] instead.
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_1/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_2/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_3/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_4/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_5/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_6/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_7/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_1/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_2/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_3/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_4/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_5/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_6/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_7/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: Tuple[Dict[str, Union[NoneType, _Dataset]], Union[Dict[str, Dict[str, PCollection]], NoneType], int] instead.
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.8 interpreter.
# 2022-11-23 12:26:25.618527: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# ExecutionResult(
#     component_id: Transform
#     execution_id: 7
#     outputs:
#         transform_graph: OutputChannel(artifact_type=TransformGraph, producer_component_id=Transform, output_key=transform_graph, additional_properties={}, additional_custom_properties={})
#         transformed_examples: OutputChannel(artifact_type=Examples, producer_component_id=Transform, output_key=transformed_examples, additional_properties={}, additional_custom_properties={})
#         updated_analyzer_cache: OutputChannel(artifact_type=TransformCache, producer_component_id=Transform, output_key=updated_analyzer_cache, additional_properties={}, additional_custom_properties={})
#         pre_transform_schema: OutputChannel(artifact_type=Schema, producer_component_id=Transform, output_key=pre_transform_schema, additional_properties={}, additional_custom_properties={})
#         pre_transform_stats: OutputChannel(artifact_type=ExampleStatistics, producer_component_id=Transform, output_key=pre_transform_stats, additional_properties={}, additional_custom_properties={})
#         post_transform_schema: OutputChannel(artifact_type=Schema, producer_component_id=Transform, output_key=post_transform_schema, additional_properties={}, additional_custom_properties={})
#         post_transform_stats: OutputChannel(artifact_type=ExampleStatistics, producer_component_id=Transform, output_key=post_transform_stats, additional_properties={}, additional_custom_properties={})
#         post_transform_anomalies: OutputChannel(artifact_type=ExampleAnomalies, producer_component_id=Transform, output_key=post_transform_anomalies, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# You can see a sample result for one row with the code below. Notice that the numeric features are indeed scaled and the categorical features are now one-hot encoded.

# %%
# Get the URI of the output artifact representing the transformed examples
train_uri = os.path.join(transform.outputs['transformed_examples'].get()[0].uri, 'Split-train')

# Get the list of files in this directory (all compressed TFRecord files)
tfrecord_filenames = [os.path.join(train_uri, name)
                      for name in os.listdir(train_uri)]

# Create a `TFRecordDataset` to read these files
dataset = tf.data.TFRecordDataset(tfrecord_filenames, compression_type="GZIP")

# Decode the first record and print output
for tfrecord in dataset.take(1):
  serialized_example = tfrecord.numpy()
  example = tf.train.Example()
  example.ParseFromString(serialized_example)
  pp.pprint(example)
# Out:
# features {
#   feature {
#     key: "age"
#     value {
#       float_list {
#         value: 0.0
#         value: 0.0
#         value: 1.0
#         value: 0.0
#       }
#     }
#   }
#   feature {
#     key: "capital-gain"
#     value {
#       float_list {
#         value: 0.02174021676182747
#       }
#     }
#   }
#   feature {
#     key: "capital-loss"
#     value {
#       float_list {
#         value: 0.0
#       }
#     }
#   }
#   feature {
#     key: "education"
#     value {
#       float_list {
#         value: 0.0
#         value: 0.0
#         value: 1.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#       }
#     }
#   }
#   feature {
#     key: "education-num"
#     value {
#       float_list {
#         value: 0.800000011920929
#       }
#     }
#   }
#   feature {
#     key: "fnlwgt"
#     value {
#       float_list {
#         value: 0.044301897287368774
#       }
#     }
#   }
#   feature {
#     key: "hours-per-week"
#     value {
#       float_list {
#         value: 0.3979591727256775
#       }
#     }
#   }
#   feature {
#     key: "label"
#     value {
#       float_list {
#         value: 0.0
#       }
#     }
#   }
#   feature {
#     key: "marital-status"
#     value {
#       float_list {
#         value: 0.0
#         value: 1.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#       }
#     }
#   }
#   feature {
#     key: "native-country"
#     value {
#       float_list {
#         value: 1.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#       }
#     }
#   }
#   feature {
#     key: "occupation"
#     value {
#       float_list {
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 1.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#       }
#     }
#   }
#   feature {
#     key: "race"
#     value {
#       float_list {
#         value: 1.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#       }
#     }
#   }
#   feature {
#     key: "relationship"
#     value {
#       float_list {
#         value: 0.0
#         value: 1.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#       }
#     }
#   }
#   feature {
#     key: "sex"
#     value {
#       float_list {
#         value: 1.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#       }
#     }
#   }
#   feature {
#     key: "workclass"
#     value {
#       float_list {
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 1.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#       }
#     }
#   }
# }

# %% [markdown]
# As you already know, the `Transform` component not only outputs the transformed examples but also the transformation graph. This should be used on all inputs when your model is deployed to ensure that it is transformed the same way as your training data. Else, it can produce training-serving skew which leads to noisy predictions.
#
# The `Transform` component stores related files in its `transform_graph` output and it would be good to quickly review its contents before we move on to the next component. As shown below, the URI of this output points to a directory containing three subdirectories.

# %%
# Get URI and list subdirectories
graph_uri = transform.outputs['transform_graph'].get()[0].uri
os.listdir(graph_uri)
# Out:
# ['transformed_metadata', 'transform_fn', 'metadata']

# %% [markdown]
# * The `transformed_metadata` subdirectory contains the schema of the preprocessed data.
# * The `transform_fn` subdirectory contains the actual preprocessing graph.
# * The `metadata` subdirectory contains the schema of the original data.

# %% [markdown]
# ### Trainer
#
# Next, you will now build the model to make your predictions. As mentioned earlier, this is a binary classifier where the label is 1 if a person earns more than 50k USD and 0 if less than or equal. The model used here uses the [wide and deep model](https://ai.googleblog.com/2016/06/wide-deep-learning-better-together-with.html) as reference but feel free to modify after you've completed the exercise. Also for simplicity, the hyperparameters (e.g. number of hidden units) have been hardcoded but feel free to use a `Tuner` component as you did in Week 1 if you want to get some practice.
#
# As a reminder, it is best to start from `run_fn()` when you're reviewing the module file below. The `Trainer` component looks for that function first. All other functions defined in the module are just utility functions for `run_fn()`.
#
# Another thing you will notice below is the `_get_serve_tf_examples_fn()` function. This is tied to the `serving_default` [signature](https://www.tensorflow.org/guide/saved_model#specifying_signatures_during_export) which makes it possible for you to just pass in raw features when the model is served for inference. You have seen this in action in the previous lab. This is done by decorating the enclosing function, `serve_tf_examples_fn()`, with [tf.function](https://www.tensorflow.org/guide/intro_to_graphs). This indicates that the computation will be done by first tracing a [Tensorflow graph](https://www.tensorflow.org/api_docs/python/tf/Graph). You will notice that this function uses `model.tft_layer` which comes from `transform_graph` output. Now when you call the `.get_concrete_function()` method on this tf.function in `run_fn()`, you are creating the graph that will be used in later computations. This graph is used whenever you pass in an `examples` argument pointing to a Tensor with `tf.string` dtype. That matches the format of the serialized batches of data you used in the previous lab.

# %%
# Declare trainer module file
_census_trainer_module_file = 'census_trainer.py'

# %%
# %%writefile {_census_trainer_module_file}
#
# from typing import List, Text
#
# import tensorflow as tf
# import tensorflow_transform as tft
# from tensorflow_transform.tf_metadata import schema_utils
#
# from tfx.components.trainer.fn_args_utils import DataAccessor, FnArgs
# from tfx_bsl.public.tfxio import TensorFlowDatasetOptions
#
# # import same constants from transform module
# import census_constants
#
# # Unpack the contents of the constants module
# _NUMERIC_FEATURE_KEYS = census_constants.NUMERIC_FEATURE_KEYS
# _VOCAB_FEATURE_DICT = census_constants.VOCAB_FEATURE_DICT
# _BUCKET_FEATURE_DICT = census_constants.BUCKET_FEATURE_DICT
# _NUM_OOV_BUCKETS = census_constants.NUM_OOV_BUCKETS
# _LABEL_KEY = census_constants.LABEL_KEY
#
#
# def _gzip_reader_fn(filenames):
#   '''Load compressed dataset
#
#   Args:
#     filenames - filenames of TFRecords to load
#
#   Returns:
#     TFRecordDataset loaded from the filenames
#   '''
#
#   # Load the dataset. Specify the compression type since it is saved as `.gz`
#   return tf.data.TFRecordDataset(filenames, compression_type='GZIP')
#
#
# def _input_fn(file_pattern,
#               tf_transform_output,
#               num_epochs=None,
#               batch_size=32) -> tf.data.Dataset:
#   '''Create batches of features and labels from TF Records
#
#   Args:
#     file_pattern - List of files or patterns of file paths containing Example records.
#     tf_transform_output - transform output graph
#     num_epochs - Integer specifying the number of times to read through the dataset.
#             If None, cycles through the dataset forever.
#     batch_size - An int representing the number of records to combine in a single batch.
#
#   Returns:
#     A dataset of dict elements, (or a tuple of dict elements and label).
#     Each dict maps feature keys to Tensor or SparseTensor objects.
#   '''
#
#   # Get post-transfrom feature spec
#   transformed_feature_spec = (
#       tf_transform_output.transformed_feature_spec().copy())
#
#   # Create batches of data
#   dataset = tf.data.experimental.make_batched_features_dataset(
#       file_pattern=file_pattern,
#       batch_size=batch_size,
#       features=transformed_feature_spec,
#       reader=_gzip_reader_fn,
#       num_epochs=num_epochs,
#       label_key=_LABEL_KEY
#       )
#
#   return dataset
#
#
# def _get_serve_tf_examples_fn(model, tf_transform_output):
#   """Returns a function that parses a serialized tf.Example and applies TFT."""
#
#   # Get transformation graph
#   model.tft_layer = tf_transform_output.transform_features_layer()
#
#   @tf.function
#   def serve_tf_examples_fn(serialized_tf_examples):
#     """Returns the output to be used in the serving signature."""
#     # Get pre-transform feature spec
#     feature_spec = tf_transform_output.raw_feature_spec()
#
#     # Pop label since serving inputs do not include the label
#     feature_spec.pop(_LABEL_KEY)
#
#     # Parse raw examples into a dictionary of tensors matching the feature spec
#     parsed_features = tf.io.parse_example(serialized_tf_examples, feature_spec)
#
#     # Transform the raw examples using the transform graph
#     transformed_features = model.tft_layer(parsed_features)
#
#     # Get predictions using the transformed features
#     return model(transformed_features)
#
#   return serve_tf_examples_fn
#
#
# def _build_keras_model(hidden_units: List[int] = None) -> tf.keras.Model:
#   """Creates a DNN Keras model for classifying income data.
#
#   Args:
#     hidden_units: [int], the layer sizes of the DNN (input layer first).
#
#   Returns:
#     A keras Model.
#   """
#
#   # Use helper function to create the model
#   model = _wide_and_deep_classifier(
#       dnn_hidden_units=hidden_units or [100, 70, 50, 25])
#
#   return model
#
#
# def _wide_and_deep_classifier(dnn_hidden_units):
#   """Build a simple keras wide and deep model using the Functional API.
#
#   Args:
#     wide_columns: Feature columns wrapped in indicator_column for wide (linear)
#       part of the model.
#     deep_columns: Feature columns for deep part of the model.
#     dnn_hidden_units: [int], the layer sizes of the hidden DNN.
#
#   Returns:
#     A Wide and Deep Keras model
#   """
#
#   # Define input layers for numeric keys
#   input_numeric = [
#       tf.keras.layers.Input(name=colname, shape=(1,), dtype=tf.float32)
#       for colname in _NUMERIC_FEATURE_KEYS
#   ]
#
#   # Define input layers for vocab keys
#   input_categorical = [
#       tf.keras.layers.Input(name=colname, shape=(vocab_size + _NUM_OOV_BUCKETS,), dtype=tf.float32)
#       for colname, vocab_size in _VOCAB_FEATURE_DICT.items()
#   ]
#
#   # Define input layers for bucket key
#   input_categorical += [
#       tf.keras.layers.Input(name=colname, shape=(num_buckets,), dtype=tf.float32)
#       for colname, num_buckets in _BUCKET_FEATURE_DICT.items()
#   ]
#
#   # Concatenate numeric inputs
#   deep = tf.keras.layers.concatenate(input_numeric)
#
#   # Create deep dense network for numeric inputs
#   for numnodes in dnn_hidden_units:
#     deep = tf.keras.layers.Dense(numnodes)(deep)
#
#   # Concatenate categorical inputs
#   wide = tf.keras.layers.concatenate(input_categorical)
#
#   # Create shallow dense network for categorical inputs
#   wide = tf.keras.layers.Dense(128, activation='relu')(wide)
#
#   # Combine wide and deep networks
#   combined = tf.keras.layers.concatenate([deep, wide])
#
#   # Define output of binary classifier
#   output = tf.keras.layers.Dense(
#       1, activation='sigmoid')(combined)
#
#   # Setup combined input
#   input_layers = input_numeric + input_categorical
#
#   # Create the Keras model
#   model = tf.keras.Model(input_layers, output)
#
#   # Define training parameters
#   model.compile(
#       loss='binary_crossentropy',
#       optimizer=tf.keras.optimizers.Adam(lr=0.001),
#       metrics='binary_accuracy')
#
#   # Print model summary
#   model.summary()
#
#   return model
#
#
# # TFX Trainer will call this function.
# def run_fn(fn_args: FnArgs):
#   """Defines and trains the model.
#
#   Args:
#     fn_args: Holds args as name/value pairs. Refer here for the complete attributes:
#     https://www.tensorflow.org/tfx/api_docs/python/tfx/components/trainer/fn_args_utils/FnArgs#attributes
#   """
#
#   # Number of nodes in the first layer of the DNN
#   first_dnn_layer_size = 100
#   num_dnn_layers = 4
#   dnn_decay_factor = 0.7
#
#   # Get transform output (i.e. transform graph) wrapper
#   tf_transform_output = tft.TFTransformOutput(fn_args.transform_output)
#
#   # Create batches of train and eval sets
#   train_dataset = _input_fn(fn_args.train_files[0], tf_transform_output, 10)
#   eval_dataset = _input_fn(fn_args.eval_files[0], tf_transform_output, 10)
#
#   # Build the model
#   model = _build_keras_model(
#       # Construct layers sizes with exponential decay
#       hidden_units=[
#           max(2, int(first_dnn_layer_size * dnn_decay_factor**i))
#           for i in range(num_dnn_layers)
#       ])
#
#   # Callback for TensorBoard
#   tensorboard_callback = tf.keras.callbacks.TensorBoard(
#       log_dir=fn_args.model_run_dir, update_freq='batch')
#
#
#   # Train the model
#   model.fit(
#       train_dataset,
#       steps_per_epoch=fn_args.train_steps,
#       validation_data=eval_dataset,
#       validation_steps=fn_args.eval_steps,
#       callbacks=[tensorboard_callback])
#
#
#   # Define default serving signature
#   signatures = {
#       'serving_default':
#           _get_serve_tf_examples_fn(model,
#                                     tf_transform_output).get_concrete_function(
#                                         tf.TensorSpec(
#                                             shape=[None],
#                                             dtype=tf.string,
#                                             name='examples')),
#   }
#
#
#   # Save model with signature
#   model.save(fn_args.serving_model_dir, save_format='tf', signatures=signatures)
# Out:
# Writing census_trainer.py

# %% [markdown]
# Now, we pass in this model code to the `Trainer` component and run it to train the model.

# %%
trainer = tfx.components.Trainer(
    module_file=os.path.abspath(_census_trainer_module_file),
    examples=transform.outputs['transformed_examples'],
    transform_graph=transform.outputs['transform_graph'],
    schema=schema_gen.outputs['schema'],
    train_args=tfx.proto.TrainArgs(num_steps=50),
    eval_args=tfx.proto.EvalArgs(num_steps=50))
context.run(trainer, enable_cache=False)
# Out:
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying census_transform.py -> build/lib
# copying census_constants.py -> build/lib
# copying census_trainer.py -> build/lib
# installing to /tmp/tmpiqzz53ky
# running install
# running install_lib
# copying build/lib/census_transform.py -> /tmp/tmpiqzz53ky
# copying build/lib/census_constants.py -> /tmp/tmpiqzz53ky
# copying build/lib/census_trainer.py -> /tmp/tmpiqzz53ky
# running install_egg_info
# running egg_info
# creating tfx_user_code_Trainer.egg-info
# writing tfx_user_code_Trainer.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Trainer.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Trainer.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# Copying tfx_user_code_Trainer.egg-info to /tmp/tmpiqzz53ky/tfx_user_code_Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94-py3.8.egg-info
# running install_scripts
# listing git files failed - pretending there aren't any
# creating /tmp/tmpiqzz53ky/tfx_user_code_Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94.dist-info/WHEEL
# creating '/tmp/tmpi0dr2fz6/tfx_user_code_Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94-py3-none-any.whl' and adding '/tmp/tmpiqzz53ky' to it
# adding 'census_constants.py'
# adding 'census_trainer.py'
# adding 'census_transform.py'
# adding 'tfx_user_code_Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94.dist-info/METADATA'
# adding 'tfx_user_code_Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94.dist-info/WHEEL'
# adding 'tfx_user_code_Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94.dist-info/top_level.txt'
# adding 'tfx_user_code_Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94.dist-info/RECORD'
# removing /tmp/tmpiqzz53ky
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# Processing ./pipeline/_wheels/tfx_user_code_Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94-py3-none-any.whl
# Installing collected packages: tfx-user-code-Trainer
# Successfully installed tfx-user-code-Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  fnlwgt (InputLayer)            [(None, 1)]          0           []
#
#  education-num (InputLayer)     [(None, 1)]          0           []
#
#  capital-gain (InputLayer)      [(None, 1)]          0           []
#
#  capital-loss (InputLayer)      [(None, 1)]          0           []
#
#  hours-per-week (InputLayer)    [(None, 1)]          0           []
#
#  concatenate (Concatenate)      (None, 5)            0           ['fnlwgt[0][0]',
#                                                                   'education-num[0][0]',
#                                                                   'capital-gain[0][0]',
#                                                                   'capital-loss[0][0]',
#                                                                   'hours-per-week[0][0]']
#
#  dense (Dense)                  (None, 100)          600         ['concatenate[0][0]']
#
#  dense_1 (Dense)                (None, 70)           7070        ['dense[0][0]']
#
#  education (InputLayer)         [(None, 21)]         0           []
#
#  marital-status (InputLayer)    [(None, 12)]         0           []
#
#  occupation (InputLayer)        [(None, 20)]         0           []
#
#  race (InputLayer)              [(None, 10)]         0           []
#
#  relationship (InputLayer)      [(None, 11)]         0           []
#
#  workclass (InputLayer)         [(None, 14)]         0           []
#
#  sex (InputLayer)               [(None, 7)]          0           []
#
#  native-country (InputLayer)    [(None, 47)]         0           []
#
#  age (InputLayer)               [(None, 4)]          0           []
#
#  dense_2 (Dense)                (None, 48)           3408        ['dense_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 146)          0           ['education[0][0]',
#                                                                   'marital-status[0][0]',
# /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
#                                                                   'occupation[0][0]',
#                                                                   'race[0][0]',
#                                                                   'relationship[0][0]',
#                                                                   'workclass[0][0]',
#                                                                   'sex[0][0]',
#                                                                   'native-country[0][0]',
#                                                                   'age[0][0]']
#
#  dense_3 (Dense)                (None, 34)           1666        ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 128)          18816       ['concatenate_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 162)          0           ['dense_3[0][0]',
#                                                                   'dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 1)            163         ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 31,723
# Trainable params: 31,723
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 50/50 [==============================] - 2s 18ms/step - loss: 0.5158 - binary_accuracy: 0.7462 - val_loss: 0.4301 - val_binary_accuracy: 0.7806
# ExecutionResult(
#     component_id: Trainer
#     execution_id: 8
#     outputs:
#         model: OutputChannel(artifact_type=Model, producer_component_id=Trainer, output_key=model, additional_properties={}, additional_custom_properties={})
#         model_run: OutputChannel(artifact_type=ModelRun, producer_component_id=Trainer, output_key=model_run, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# Let's review the outputs of this component. The `model` output points to the model output itself.

# %%
# Get `model` output of the component
model_artifact_dir = trainer.outputs['model'].get()[0].uri

# List top-level directory
pp.pprint(os.listdir(model_artifact_dir))

# Get model directory
model_dir = os.path.join(model_artifact_dir, 'Format-Serving')

# List subdirectories
pp.pprint(os.listdir(model_dir))
# Out:
# ['Format-Serving']
# ['keras_metadata.pb', 'saved_model.pb', 'assets', 'variables']

# %% [markdown]
# The `model_run` output acts as the working directory and can be used to output non-model related output (e.g., TensorBoard logs).

# %%
# Get `model_run` output URI
model_run_artifact_dir = trainer.outputs['model_run'].get()[0].uri

# Load results to Tensorboard
# %load_ext tensorboard
# %tensorboard --logdir {model_run_artifact_dir}
# Out:
#       <iframe id="tensorboard-frame-727676f716c65300" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-727676f716c65300");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### Evaluator
#
# The `Evaluator` component computes model performance metrics over the evaluation set using the [TensorFlow Model Analysis](https://www.tensorflow.org/tfx/model_analysis/get_started) library. The `Evaluator` can also optionally validate that a newly trained model is better than the previous model. This is useful in a production pipeline setting where you may automatically train and validate a model every day.
#
# There's a few steps needed to setup this component and you will do it in the next cells.

# %% [markdown]
# #### Define EvalConfig
#
# First, you will define the `EvalConfig` message as you did in the previous lab. You can also set thresholds so you can compare subsequent models to it. The module below should look familiar. One minor difference is you don't have to define the candidate and baseline model names in the `model_specs`. That is automatically detected.

# %%
import tensorflow_model_analysis as tfma
from google.protobuf import text_format

eval_config = text_format.Parse("""
  ## Model information
  model_specs {
    # This assumes a serving model with signature 'serving_default'.
    signature_name: "serving_default",
    label_key: "label"
  }

  ## Post training metric information
  metrics_specs {
    metrics { class_name: "ExampleCount" }
    metrics {
      class_name: "BinaryAccuracy"
      threshold {
        # Ensure that metric is always > 0.5
        value_threshold {
          lower_bound { value: 0.5 }
        }
        # Ensure that metric does not drop by more than a small epsilon
        # e.g. (candidate - baseline) > -1e-10 or candidate > baseline - 1e-10
        change_threshold {
          direction: HIGHER_IS_BETTER
          absolute { value: -1e-10 }
        }
      }
    }
    metrics { class_name: "BinaryCrossentropy" }
    metrics { class_name: "AUC" }
    metrics { class_name: "AUCPrecisionRecall" }
    metrics { class_name: "Precision" }
    metrics { class_name: "Recall" }
    metrics { class_name: "MeanLabel" }
    metrics { class_name: "MeanPrediction" }
    metrics { class_name: "Calibration" }
    metrics { class_name: "CalibrationPlot" }
    metrics { class_name: "ConfusionMatrixPlot" }
    # ... add additional metrics and plots ...
  }

  ## Slicing information
  slicing_specs {}  # overall slice
  slicing_specs {
    feature_keys: ["race"]
  }
  slicing_specs {
    feature_keys: ["sex"]
  }
""", tfma.EvalConfig())

# %% [markdown]
# #### Resolve latest blessed model
#
# If you remember in the last lab, you were able to validate a candidate model against a baseline by modifying the `EvalConfig` and `EvalSharedModel` definitions. That is also possible using the `Evaluator` component and you will see how it is done in this section.
#
# First thing to note is that the `Evaluator` marks a model as `BLESSED` if it meets the metrics thresholds you set in the eval config module. You can load the latest blessed model by using the [`LatestBlessedModelStrategy`](https://www.tensorflow.org/tfx/api_docs/python/tfx/dsl/input_resolution/strategies/latest_blessed_model_strategy/LatestBlessedModelStrategy) with the [Resolver](https://www.tensorflow.org/tfx/api_docs/python/tfx/dsl/components/common/resolver/Resolver) component. This component takes care of finding the latest blessed model for you so you don't have to remember it manually. The syntax is shown below.

# %%
# Setup the Resolver node to find the latest blessed model
model_resolver = tfx.dsl.Resolver(
      strategy_class=tfx.dsl.experimental.LatestBlessedModelStrategy,
      model=tfx.dsl.Channel(type=tfx.types.standard_artifacts.Model),
      model_blessing=tfx.dsl.Channel(
          type=tfx.types.standard_artifacts.ModelBlessing)).with_id(
              'latest_blessed_model_resolver')

# Run the Resolver node
context.run(model_resolver)
# Out:
# ExecutionResult(
#     component_id: latest_blessed_model_resolver
#     execution_id: 9
#     outputs:
#         model: OutputChannel(artifact_type=Model, producer_component_id=latest_blessed_model_resolver, output_key=model, additional_properties={}, additional_custom_properties={})
#         model_blessing: OutputChannel(artifact_type=ModelBlessing, producer_component_id=latest_blessed_model_resolver, output_key=model_blessing, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# As expected, the search yielded 0 artifacts because you haven't evaluated any models yet. You will run this component again in later parts of this notebook and you will see a different result.

# %%
# Load Resolver outputs
model_resolver.outputs['model']
# Out:
# OutputChannel(artifact_type=Model, producer_component_id=latest_blessed_model_resolver, output_key=model, additional_properties={}, additional_custom_properties={})

# %% [markdown]
# #### Run the Evaluator component
#
# With the `EvalConfig` defined and code to load the latest blessed model available, you can proceed to run the `Evaluator` component.
#
# You will notice that two models are passed into the component. The `Trainer` output will serve as the candidate model while the output of the `Resolver` will be the baseline model. While you can indeed run the `Evaluator` without comparing two models, it would likely be required in production environments so it's best to include it. Since the `Resolver` doesn't have any results yet, the `Evaluator` will just mark the candidate model as `BLESSED` in this run.
#
# Aside from the eval config and models (i.e. Trainer and Resolver output), you will also pass in the *raw* examples from `ExampleGen`. By default, the component will look for the `eval` split of these examples and since you've defined the serving signature, these will be transformed internally before feeding to the model inputs.

# %%
# Setup and run the Evaluator component
evaluator = tfx.components.Evaluator(
    examples=example_gen.outputs['examples'],
    model=trainer.outputs['model'],
    baseline_model=model_resolver.outputs['model'],
    eval_config=eval_config)
context.run(evaluator, enable_cache=False)
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.8 interpreter.
# /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages/tensorflow_model_analysis/metrics/confusion_matrix_metrics.py:482: RuntimeWarning: invalid value encountered in true_divide
#   prec_slope = dtp / np.maximum(dp, 0)
# /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages/tensorflow_model_analysis/metrics/confusion_matrix_metrics.py:486: RuntimeWarning: divide by zero encountered in true_divide
#   p[:num_thresholds - 1] / np.maximum(p[1:], 0), np.ones_like(p[1:]))
# /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages/tensorflow_model_analysis/metrics/confusion_matrix_metrics.py:486: RuntimeWarning: invalid value encountered in true_divide
#   p[:num_thresholds - 1] / np.maximum(p[1:], 0), np.ones_like(p[1:]))
# ExecutionResult(
#     component_id: Evaluator
#     execution_id: 10
#     outputs:
#         evaluation: OutputChannel(artifact_type=ModelEvaluation, producer_component_id=Evaluator, output_key=evaluation, additional_properties={}, additional_custom_properties={})
#         blessing: OutputChannel(artifact_type=ModelBlessing, producer_component_id=Evaluator, output_key=blessing, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# Now let's examine the output artifacts of `Evaluator`.

# %%
# Print component output keys
evaluator.outputs.keys()
# Out:
# dict_keys(['evaluation', 'blessing'])

# %% [markdown]
# The `blessing` output simply states if the candidate model was blessed. The artifact URI will have a `BLESSED` or `NOT_BLESSED` file depending on the result. As mentioned earlier, this first run will pass the evaluation because there is no baseline model yet.

# %%
# Get `Evaluator` blessing output URI
blessing_uri = evaluator.outputs['blessing'].get()[0].uri

# List files under URI
os.listdir(blessing_uri)
# Out:
# ['BLESSED']

# %% [markdown]
# The `evaluation` output, on the other hand, contains the evaluation logs and can be used to visualize the global metrics on the entire evaluation set.

# %%
# Visualize the evaluation results
context.show(evaluator.outputs['evaluation'])
# Out:
# <b>Artifact at ./pipeline/Evaluator/evaluation/10</b><br/><br/>

# %% [markdown]
# To see the individual slices, you will need to import TFMA and use the commands you learned in the previous lab.

# %%
import tensorflow_model_analysis as tfma

# Get the TFMA output result path and load the result.
PATH_TO_RESULT = evaluator.outputs['evaluation'].get()[0].uri
tfma_result = tfma.load_eval_result(PATH_TO_RESULT)

# Show data sliced along feature column trip_start_hour.
tfma.view.render_slicing_metrics(
    tfma_result, slicing_column='sex')
# Out:
# SlicingMetricsViewer(config={'weightedExamplesColumn': 'example_count'}, data=[{'slice': 'sex:Male', 'metrics'…

# %% [markdown]
# You can also use TFMA to load the validation results as before by specifying the output URI of the evaluation output. This would be more useful if your model was not blessed because you can see the metric failure prompts. Try to simulate this later by training with fewer epochs (or raising the threshold) and see the results you get here.

# %%
# Get `evaluation` output URI
PATH_TO_RESULT = evaluator.outputs['evaluation'].get()[0].uri

# Print validation result
print(tfma.load_validation_result(PATH_TO_RESULT))
# Out:
# validation_ok: true
# validation_details {
#   slicing_details {
#     slicing_spec {
#     }
#     num_matching_slices: 8
#   }
# }

# %% [markdown]
# Now that your `Evaluator` has finished running, the `Resolver` component should be able to detect the latest blessed model. Let's run the component again.

# %%
# Re-run the Resolver component
context.run(model_resolver)
# Out:
# ExecutionResult(
#     component_id: latest_blessed_model_resolver
#     execution_id: 11
#     outputs:
#         model: OutputChannel(artifact_type=Model, producer_component_id=latest_blessed_model_resolver, output_key=model, additional_properties={}, additional_custom_properties={})
#         model_blessing: OutputChannel(artifact_type=ModelBlessing, producer_component_id=latest_blessed_model_resolver, output_key=model_blessing, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# You should now see an artifact in the component outputs. You can also get it programmatically as shown below.

# %%
# Get path to latest blessed model
model_resolver.outputs['model'].get()[0].uri
# Out:
# './pipeline/Trainer/model/8'

# %% [markdown]
# #### Comparing two models
#
# Now let's see how `Evaluator` compares two models. You will train the same model with more epochs and this should hopefully result in higher accuracy and overall metrics.

# %%
# Setup trainer to train with more epochs
trainer = tfx.components.Trainer(
    module_file=os.path.abspath(_census_trainer_module_file),
    examples=transform.outputs['transformed_examples'],
    transform_graph=transform.outputs['transform_graph'],
    schema=schema_gen.outputs['schema'],
    train_args=tfx.proto.TrainArgs(num_steps=500),
    eval_args=tfx.proto.EvalArgs(num_steps=200))

# Run trainer
context.run(trainer, enable_cache=False)
# Out:
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying census_transform.py -> build/lib
# copying census_constants.py -> build/lib
# copying census_trainer.py -> build/lib
# installing to /tmp/tmp73alkj5m
# running install
# running install_lib
# copying build/lib/census_transform.py -> /tmp/tmp73alkj5m
# copying build/lib/census_constants.py -> /tmp/tmp73alkj5m
# copying build/lib/census_trainer.py -> /tmp/tmp73alkj5m
# running install_egg_info
# running egg_info
# creating tfx_user_code_Trainer.egg-info
# writing tfx_user_code_Trainer.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Trainer.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Trainer.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# listing git files failed - pretending there aren't any
# reading manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# Copying tfx_user_code_Trainer.egg-info to /tmp/tmp73alkj5m/tfx_user_code_Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94-py3.8.egg-info
# running install_scripts
# creating /tmp/tmp73alkj5m/tfx_user_code_Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94.dist-info/WHEEL
# creating '/tmp/tmpzju5v33d/tfx_user_code_Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94-py3-none-any.whl' and adding '/tmp/tmp73alkj5m' to it
# adding 'census_constants.py'
# adding 'census_trainer.py'
# adding 'census_transform.py'
# adding 'tfx_user_code_Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94.dist-info/METADATA'
# adding 'tfx_user_code_Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94.dist-info/WHEEL'
# adding 'tfx_user_code_Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94.dist-info/top_level.txt'
# adding 'tfx_user_code_Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94.dist-info/RECORD'
# removing /tmp/tmp73alkj5m
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# Processing ./pipeline/_wheels/tfx_user_code_Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94-py3-none-any.whl
# Installing collected packages: tfx-user-code-Trainer
# Successfully installed tfx-user-code-Trainer-0.0+479877abccbf9c1af6f7cd5677b42a0778205b6c6b3699984a7cf887ca834d94
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  fnlwgt (InputLayer)            [(None, 1)]          0           []
#
#  education-num (InputLayer)     [(None, 1)]          0           []
#
#  capital-gain (InputLayer)      [(None, 1)]          0           []
#
#  capital-loss (InputLayer)      [(None, 1)]          0           []
#
#  hours-per-week (InputLayer)    [(None, 1)]          0           []
#
#  concatenate_3 (Concatenate)    (None, 5)            0           ['fnlwgt[0][0]',
#                                                                   'education-num[0][0]',
#                                                                   'capital-gain[0][0]',
#                                                                   'capital-loss[0][0]',
#                                                                   'hours-per-week[0][0]']
#
#  dense_6 (Dense)                (None, 100)          600         ['concatenate_3[0][0]']
#
#  dense_7 (Dense)                (None, 70)           7070        ['dense_6[0][0]']
#
#  education (InputLayer)         [(None, 21)]         0           []
#
#  marital-status (InputLayer)    [(None, 12)]         0           []
#
#  occupation (InputLayer)        [(None, 20)]         0           []
#
#  race (InputLayer)              [(None, 10)]         0           []
#
#  relationship (InputLayer)      [(None, 11)]         0           []
#
#  workclass (InputLayer)         [(None, 14)]         0           []
#
#  sex (InputLayer)               [(None, 7)]          0           []
# /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
#  native-country (InputLayer)    [(None, 47)]         0           []
#
#  age (InputLayer)               [(None, 4)]          0           []
#
#  dense_8 (Dense)                (None, 48)           3408        ['dense_7[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 146)          0           ['education[0][0]',
#                                                                   'marital-status[0][0]',
#                                                                   'occupation[0][0]',
#                                                                   'race[0][0]',
#                                                                   'relationship[0][0]',
#                                                                   'workclass[0][0]',
#                                                                   'sex[0][0]',
#                                                                   'native-country[0][0]',
#                                                                   'age[0][0]']
#
#  dense_9 (Dense)                (None, 34)           1666        ['dense_8[0][0]']
#
#  dense_10 (Dense)               (None, 128)          18816       ['concatenate_4[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 162)          0           ['dense_9[0][0]',
#                                                                   'dense_10[0][0]']
#
#  dense_11 (Dense)               (None, 1)            163         ['concatenate_5[0][0]']
#
# ==================================================================================================
# Total params: 31,723
# Trainable params: 31,723
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 500/500 [==============================] - 5s 7ms/step - loss: 0.3507 - binary_accuracy: 0.8371 - val_loss: 0.3215 - val_binary_accuracy: 0.8455
# ExecutionResult(
#     component_id: Trainer
#     execution_id: 12
#     outputs:
#         model: OutputChannel(artifact_type=Model, producer_component_id=Trainer, output_key=model, additional_properties={}, additional_custom_properties={})
#         model_run: OutputChannel(artifact_type=ModelRun, producer_component_id=Trainer, output_key=model_run, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# You will re-run the evaluator but you will specify the latest trainer output as the candidate model. The baseline is automatically found with the Resolver node.

# %%
# Setup and run the Evaluator component
evaluator = tfx.components.Evaluator(
    examples=example_gen.outputs['examples'],
    model=trainer.outputs['model'],
    baseline_model=model_resolver.outputs['model'],
    eval_config=eval_config)
context.run(evaluator, enable_cache=False)
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.8 interpreter.
# /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages/tensorflow_model_analysis/metrics/confusion_matrix_metrics.py:482: RuntimeWarning: invalid value encountered in true_divide
#   prec_slope = dtp / np.maximum(dp, 0)
# /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages/tensorflow_model_analysis/metrics/confusion_matrix_metrics.py:486: RuntimeWarning: divide by zero encountered in true_divide
#   p[:num_thresholds - 1] / np.maximum(p[1:], 0), np.ones_like(p[1:]))
# /home/tjp1992/.pyenv/versions/3.8.12/envs/coursera/lib/python3.8/site-packages/tensorflow_model_analysis/metrics/confusion_matrix_metrics.py:486: RuntimeWarning: invalid value encountered in true_divide
#   p[:num_thresholds - 1] / np.maximum(p[1:], 0), np.ones_like(p[1:]))
# ExecutionResult(
#     component_id: Evaluator
#     execution_id: 13
#     outputs:
#         evaluation: OutputChannel(artifact_type=ModelEvaluation, producer_component_id=Evaluator, output_key=evaluation, additional_properties={}, additional_custom_properties={})
#         blessing: OutputChannel(artifact_type=ModelBlessing, producer_component_id=Evaluator, output_key=blessing, additional_properties={}, additional_custom_properties={}))

# %% [markdown]
# Depending on the result, the Resolver should reflect the latest blessed model. Since you trained with more epochs, it is most likely that your candidate model will pass the thresholds you set in the eval config. If so, the artifact URI should be different here compared to your earlier runs.

# %%
# Re-run the resolver
context.run(model_resolver, enable_cache=False)
# Out:
# ExecutionResult(
#     component_id: latest_blessed_model_resolver
#     execution_id: 14
#     outputs:
#         model: OutputChannel(artifact_type=Model, producer_component_id=latest_blessed_model_resolver, output_key=model, additional_properties={}, additional_custom_properties={})
#         model_blessing: OutputChannel(artifact_type=ModelBlessing, producer_component_id=latest_blessed_model_resolver, output_key=model_blessing, additional_properties={}, additional_custom_properties={}))

# %%
# Get path to latest blessed model
model_resolver.outputs['model'].get()[0].uri
# Out:
# './pipeline/Trainer/model/12'

# %% [markdown]
# Finally, the `evaluation` output of the `Evaluator` component will now be able to produce the `diff` results you saw in the previous lab. This will signify if the metrics from the candidate model has indeed improved compared to the baseline. Unlike when using TFMA as a standalone library, visualizing this will just show the results for the candidate (i.e. only one row instead of two in the tabular output in the graph below).
#
# *Note: You can ignore the warning about failing to find plots.*

# %%
context.show(evaluator.outputs['evaluation'])
# Out:
# <b>Artifact at ./pipeline/Evaluator/evaluation/13</b><br/><br/>
# WARNING:absl:Fail to find plots for model name: None . Available model names are [candidate, baseline]
# WARNING:absl:Fail to find plots for model name: None . Available model names are [candidate, baseline]
# WARNING:absl:Fail to find plots for model name: None . Available model names are [candidate, baseline]
# WARNING:absl:Fail to find plots for model name: None . Available model names are [candidate, baseline]
# WARNING:absl:Fail to find plots for model name: None . Available model names are [candidate, baseline]
# WARNING:absl:Fail to find plots for model name: None . Available model names are [candidate, baseline]
# WARNING:absl:Fail to find plots for model name: None . Available model names are [candidate, baseline]
# WARNING:absl:Fail to find plots for model name: None . Available model names are [candidate, baseline]

# %% [markdown]
# **Congratulations! You can now successfully evaluate your models in a TFX pipeline! This is a critical part of production ML because you want to make sure that subsequent deployments are indeed improving your results. Moreover, you can extract the evaluation results from your pipeline directory for further investigation with TFMA. In the next sections, you will continue to study techniques related to model evaluation and ensuring fairness.**
